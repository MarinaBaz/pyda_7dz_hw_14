# %% [markdown]
# # Домашняя работа по визуализации к лекции 14

# %%
#увеличим дефолтный размер графиков
from pylab import rcParams
rcParams['figure.figsize'] = 10,7

# импортируем нужные библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Исходные данные: 2 файла с данными с янв 2019 по текущий момент (один с ценами, другой - с шт. проданного товара).
# * Art - артикул товара
# * Name - наименование товара
# * CostRub - суммарный товарооборот в руб. за месяц
# * Quantity - суммарный объем продаж в шт. за месяц
# * Year - год продажи
# * Month - месяц продажи
#
#
# Подготовка данных в конце ноутбука.

# %% [markdown]
# ## Визуализация и анализ данных

# %% [markdown]
# ### товарооборот
# - Art - артикул
# - Name - наименование товара
# - CostRub - суммарный товарооборот за 2019 год
#
# **Цель: подвести итоги продаж по артикулам товара в отделе 1 за 2019 год, вывести по убыванию товарооборота**
#
# Решение: воспользуемся стилизацией таблиц

# %%
data_cost1_sum.style.bar()
# Out:
# <style  type="text/css" >
#     #T_8aab910c_528c_11ea_bd67_3ca067dbb1d8row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_8aab910c_528c_11ea_bd67_3ca067dbb1d8row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.5%, transparent 51.5%);
#         }    #T_8aab910c_528c_11ea_bd67_3ca067dbb1d8row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.6%, transparent 48.6%);
#         }    #T_8aab910c_528c_11ea_bd67_3ca067dbb1d8row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.8%, transparent 45.8%);
#         }    #T_8aab910c_528c_11ea_bd67_3ca067dbb1d8row4_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# и постоим столбчатую диаграмму распределения для TOP30 товаров из этой таблицы

# %%
plt.barh(data1_top30_2['TopCost_Art'], data1_top30_2['CostRub_x'])
# Out:
# <BarContainer object of 356 artists>

# %% [markdown]
# ### кол-во продаж
# - Art - артикул
# - Name - наименование товара
# - Quantity - суммарный объем продаж в шт. за 2019 год
#
# **Цель: подвести итоги по кол-ву продаж в шт. товара в отделе 1 за 2019 год, вывести по убыванию шт.**
#
# Решение: воспользуемся стилизацией таблиц

# %%
data_quantity1_sum.style.bar()
# Out:
# <style  type="text/css" >
#     #T_cf2b5c10_528c_11ea_a738_3ca067dbb1d8row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cf2b5c10_528c_11ea_a738_3ca067dbb1d8row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.0%, transparent 78.0%);
#         }    #T_cf2b5c10_528c_11ea_a738_3ca067dbb1d8row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 70.3%, transparent 70.3%);
#         }    #T_cf2b5c10_528c_11ea_a738_3ca067dbb1d8row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.9%, transparent 59.9%);
#         }    #T_cf2b5c10_528c_11ea_a738_3ca067dbb1d8row4_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# **Вывод:**
# * МЕШОК Д/МУСОР и ПЕСКОБЕТОН AXTON занимают лидирующие места как по выручке, так и по объему продаж
# * ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ - лидирующее место по выручке, с заметным отрывом

# %% [markdown]
# ### TOP30 артикулов по продажам за 2019

# %%
#сводная таблица
data_cost1_rez2
# Out:
# TopCost_Art  01_10073940  02_18478820  03_18700540  04_15095305  05_15163427  \
# Period
# 2019-01-01        127991        76786        65500        80379        26496
# 2019-02-01        366447       114986       102760        74813        42368
# 2019-03-01        260065       109095       168278       113018       158592
# 2019-04-01        176113       133560       162243       156864       103296
# 2019-05-01        239401       101780        89775       101328       126431
# 2019-06-01        182059       138600       105840       113875       116928
# 2019-07-01        385818        72800       126628        95961        92232
# 2019-08-01        290458       152048       147705        98279       106797
# 2019-09-01        222882       146994       109965       167790        82656
# 2019-10-01        176369       216836       102030        66685       113652
# 2019-11-01        187486       125372       137590       114905       114912
# ...

# %%
#TOP5 артикулов по продажам за 2019, основная статистика
data_cost1_rez2.iloc[:,0:5].describe()
# Out:
# TopCost_Art    01_10073940    02_18478820    03_18700540    04_15095305  \
# count            12.000000      12.000000      12.000000      12.000000
# mean         242308.666667  124724.833333  117765.750000  110838.500000
# std           79766.397151   38308.464906   31061.011721   32029.771079
# min          127991.000000   72800.000000   65500.000000   66685.000000
# 25%          180636.500000  106325.750000  100241.250000   92065.500000
# 50%          231141.500000  120179.000000  107902.500000  107173.000000
# 75%          290997.250000  140698.500000  140118.750000  122720.000000
# max          385818.000000  216836.000000  168278.000000  167790.000000
#
# TopCost_Art    05_15163427
# count            12.000000
# mean         102091.833333
# std           37630.775661
# min           26496.000000
# 25%           89838.000000
# 50%          110224.500000
# 75%          119303.750000
# max          158592.000000

# %% [markdown]
# **Цель: проанализировать динамику продаж по месяцам 5-ти топовых товаров в отделе 1 за 2019 год**
#
# Решение: воспользуемся тепловой картой

# %%
#тепловая карта TOP5
ax = sns.heatmap(data_cost1_rez2.iloc[:,0:5])

# %% [markdown]
# также построим график

# %%
#график TOP5
data_cost1_rez2.iloc[:,0:5].plot()

# %% [markdown]
# построим столбчатую гистограмму

# %%
data_cost1_rez2.iloc[:,0:5].plot(kind='bar')

# %% [markdown]
# **Вывод:**
# ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ - заметна сезонность в продажах, остальные товары продаются относительно равномерно, без пиков спроса

# %% [markdown]
# ## Подготовка данных, формирование таблиц для анализа

# %% [markdown]
# ### 1. импортируем данные в ДФ (по 15 отделам строит. гипермаркета)

# %%
#data_cost = {}
#for fl in range(1,16):
#   data_cost[fl] = pd.read_csv(
#       f'cost/{fl}.csv',      
#       sep=';',
#       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
#       encoding='utf-8'  
#    )
#data_cost1.head()

# %%
data_cost1 = pd.read_csv(
       'cost/1.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost1.head()
# Out:
#         Art                                    Name  CostRub  Year    Month
# 0  10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   385818  2019     Июль
# 1  10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   366447  2019  Февраль
# 2  10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   292615  2019  Декабрь
# 3  10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   290458  2019   Август
# 4  10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   260065  2019     Март

# %%
data_cost2 = pd.read_csv(
       'cost/2.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost2.head()
# Out:
#         Art                                      Name  CostRub  Year    Month
# 0  12750159        Фанера ФК 8мм 1525х1525 4/4 нешлиф   690000  2019  Октябрь
# 1  81977449  Пан.МДФ 2600x238x6мм Дуб Мальборк 0,62м2   103680  2019      Май
# 2  81947516   ДПГ ARTENS ВЕЛДОН МОККО 2000X800 С ФУРН   100737  2019   Апрель
# 3  18693677           OSB-3 11MM ULTRALAM 1250Х2500ММ    90385  2019      Май
# 4  17854491       Стекло ПЭТ-А прозрачн.1525х1025х3мм    79860  2019     Июль

# %%
data_cost3 = pd.read_csv(
       'cost/3.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost3.head()
# Out:
#         Art                                      Name  CostRub  Year    Month
# 0  17921295  Розетка с/з с защ-й от дет керам. цв. бе   215414  2019     Июль
# 1  82035005        Кабель ВВГп-НГ 3х2,5 мм ГОСТ 100 м   173420  2019   Январь
# 2  82315576  Кабель ВВГ-Пнг(A)-LS 3х2,5 100мСевкабель   122850  2020   Январь
# 3  10061739       Выкл автомат. 1Р, C 16А 4,5 kA  АВВ   101936  2019  Октябрь
# 4  82035005        Кабель ВВГп-НГ 3х2,5 мм ГОСТ 100 м    89700  2019     Июнь

# %%
data_cost4 = pd.read_csv(
       'cost/4.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost4.head()
# Out:
#         Art                                    Name  CostRub  Year     Month
# 0  17883559     Лобзик  450 Вт STEB 65 Quick Metabo   663689  2019    Апрель
# 1  16619300  Краскопульт 650Вт 300мл/мин PFS 3000-2   265988  2019    Апрель
# 2  18769951    ПЕРФ.SDSPL 780ВТ 2,7ДЖ HR2470 MAKITA   137231  2019      Июль
# 3  18769951    ПЕРФ.SDSPL 780ВТ 2,7ДЖ HR2470 MAKITA   114886  2019  Сентябрь
# 4  18769951    ПЕРФ.SDSPL 780ВТ 2,7ДЖ HR2470 MAKITA    93470  2019    Ноябрь

# %%
data_cost5 = pd.read_csv(
       'cost/5.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost5.head()
# Out:
#         Art                                 Name  CostRub  Year    Month
# 0  82200463      Ковр/п иглопр Austin 78 черн 2м  1427712  2019  Октябрь
# 1  81947659  ПЛ ПВХ FLEXO SUMM 31/4,5/0,3 1,76M?   471276  2019  Декабрь
# 2  15300313   П/ Д ДУБ КАРАМЕЛЬ 1П ЛАК 0,909М2 Р   157624  2020   Январь
# 3  15417440  Лам 33/12 Дуб Берген 4V KX 1,293 м2   150939  2019   Январь
# 4  18268443         Лам 33/12 Помпиду TT 1,253м2   138510  2019  Декабрь

# %%
data_cost6 = pd.read_csv(
       'cost/6.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost6.head()
# Out:
#         Art                                               Name  CostRub  Year  \
# 0  81990714     Керамогр. City Squares серый 29,7x59,8, 1,6 м2   154000  2019
# 1  16379326            Керамогр EG12 30x30 непол  1сорт 1,53м2   143666  2019
# 2  81959378  Плитка настенная Антик светло бежевая20х30 1,5 м2   141122  2019
# 3  13098932                               Клей Юнис 2000 25 кг   128822  2019
# 4  12026910             Клей д/плитки слож поверх Юнис-ПЛЮС 25   123755  2019
#
#       Month
# 0      Март
# 1    Апрель
# 2      Июль
# 3  Сентябрь
# 4  Сентябрь

# %%
data_cost7 = pd.read_csv(
       'cost/7.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost7.head()
# Out:
#         Art                                   Name  CostRub  Year     Month
# 0  12281401              Ванна чугун ГРАЦИЯ 170х70   138420  2019   Декабрь
# 1  18635602  СЕТ SOLIDO (ИНСТАЛЯЦИЯ,УНИТАЗ,КНОПКА)    85288  2019  Сентябрь
# 2  18870653       Комплект с верх.душем SHOWERPIPE    74903  2019  Сентябрь
# 3  18120191    Кабина NOA 1/4 кр. 90х90, выс. под.    68200  2019   Декабрь
# 4  81983941    СЕТ CITY (ИНСТАЛЯЦИЯ,УНИТАЗ,КНОПКА)    64515  2019   Декабрь

# %%
data_cost8 = pd.read_csv(
       'cost/8.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost8.head()
# Out:
#         Art                                      Name  CostRub  Year     Month
# 0  81979195   Радиатор RT BiLiner 500/12 Silver Satin   106444  2019  Сентябрь
# 1  18360725   Радиатор биметал Equation 500/100 8 cек   106400  2019      Июнь
# 2  82395886    Радиатор стальн.трубч.TESI 21800/6 кр.   103500  2020    Январь
# 3  82395887    Радиатор стальн.трубч.TESI 21800/8 кр.    82800  2020    Январь
# 4  12876448  Радиатор биметал RIFAR MONOLIT 500 8 сек    73568  2019    Август

# %%
data_cost9 = pd.read_csv(
       'cost/9.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost9.head()
# Out:
#         Art                                    Name  CostRub  Year     Month
# 0  81955991  ТРИММЕР БЕНЗИНОВЫЙ KATANA KB-1050A PRO    85515  2019       Май
# 1  18825019            Мотокоса бенз PATRIOT PT 527    57526  2019    Апрель
# 2  16863417  Пленка п/э 150 мкм. 1,5мх2(рулон) 50м.    57304  2019      Июль
# 3  13560947  Насос фекальный с ножами DWP 18000 л/ч    42284  2019  Сентябрь
# 4  18566601        Насос фекальный с ножами FR-110R    36584  2019   Октябрь

# %%
data_cost10 = pd.read_csv(
       'cost/10.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost10.head()
# Out:
#         Art                              Name  CostRub  Year    Month
# 0  14091863     Дюбель-гвоздь Пот 6х40(600шт)    39184  2019  Декабрь
# 1  13322009  Лист алюм. АМг2 1,5х600х1200Рифл    37687  2019  Декабрь
# 2  14091863     Дюбель-гвоздь Пот 6х40(600шт)    32736  2019   Август
# 3  10175867  Доводчик 1060 (40-60кг.) серебро    30456  2019   Август
# 4  14091863     Дюбель-гвоздь Пот 6х40(600шт)    29760  2019  Октябрь

# %%
data_cost11 = pd.read_csv(
       'cost/11.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost11.head()
# Out:
#         Art                                    Name  CostRub  Year   Month
# 0  11601215   ВД краска Тиккурила EURO POWER 7 A 9л   247882  2019  Апрель
# 1  81963448  Luxens Краска д/стен гост/спальн,A 10л   222912  2019    Июль
# 2  11601215   ВД краска Тиккурила EURO POWER 7 A 9л   195976  2019     Май
# 3  81963448  Luxens Краска д/стен гост/спальн,A 10л   165317  2019  Август
# 4  81956695       CR_МАЛЯРНАЯ ЛЕНТА DEXTER 50ММX50М   157473  2019  Август

# %%
data_cost12 = pd.read_csv(
       'cost/12.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost12.head()
# Out:
#         Art                                      Name  CostRub  Year    Month
# 0  81929445  Декоратив. зеркальная плитка/Соты графит    90300  2020   Январь
# 1  81971930       Плинтус потол полиур 95775 70х70 2м    47500  2019     Март
# 2  16037297   Молдинг настен. ударопр. полимер WL1 2м    43188  2019   Апрель
# 3  18446764   Ст/обои 1х25м,Рогожка ср 110г/м бел Ins    36649  2019  Декабрь
# 4  17019293  Обои 1,06х10м флиз св беж нат штук Ins П    36569  2019     Март

# %%
data_cost13 = pd.read_csv(
       'cost/13.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost13.head()
# Out:
#         Art                                      Name  CostRub  Year    Month
# 0  18070509         Панель LED 4350lm 40Вт 4000K IP20   118626  2019   Январь
# 1  82025177     Панель диод. 595x595x8 40Вт 6500K бел    91822  2019   Ноябрь
# 2  18182228      LEDсвет-к LLFW 36W 2520Lm IP20 6500К    75260  2019  Февраль
# 3  81970038  ТОП1000 ПАНЕЛЬ LED 4350LM 40ВТ4000K IP20    74385  2019   Ноябрь
# 4  81952475   LED панель 6561-Р 36Вт 4000К призма IEK    69984  2019     Март

# %%
data_cost14 = pd.read_csv(
       'cost/14.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost14.head()
# Out:
#         Art                                      Name  CostRub  Year     Month
# 0  14643314            СТЕЛЛАЖ 200Х100Х50 НАГР.100 КГ    74580  2019      Июнь
# 1  14643314            СТЕЛЛАЖ 200Х100Х50 НАГР.100 КГ    58838  2019      Март
# 2  18635362  Стеллаж металл 100х40х200 4 полки 150 кг    52386  2019      Июль
# 3  18635371  Стеллаж  металл 100х50х200см 4 полки  15    42588  2019  Сентябрь
# 4  18333727        Дверь-купе Spaceo 2555х804 Зеркало    42488  2019   Февраль

# %%
data_cost15 = pd.read_csv(
       'cost/15.csv',      
       sep=';',
       names=['Art', 'Name', 'CostRub', 'Year', 'Month'],
       encoding='utf-8'  
    )
data_cost15.head()
# Out:
#         Art                                      Name  CostRub  Year     Month
# 0  81948546  ДУХ.ШК.С ПАРОМ ELECTROLUX OPEA4554X,НЕРЖ    62920  2019  Сентябрь
# 1  18651717       ХОЛ ВСТР В178ХД54ХГ54 HANSA BK316.3    51286  2019       Май
# 2  81948547         ПММ ВСТР 45 ELECTROLUX ESL94200LO    40766  2019  Сентябрь
# 3  82003878  Х0Л ВСТР 178Х54Х54 HOTPOINT BCB 70301 AA    39990  2019    Август
# 4  82125563          Столешница Бук массив 240х60х4см    33924  2019    Август

# %%
#data_quantity = {}
#for fl in range(1,16):
#   data_quantity[fl] = pd.read_csv(
#       f'quantity/{fl}.csv',
#       sep=';',
#       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
#       encoding='utf-8'       
#    )
#data_quantity1.head()

# %%
data_quantity1 = pd.read_csv(
       'quantity/1.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity1.head()
# Out:
#         Art                                    Name  Year   Month  Quantity
# 0  14394434      Прямой подвес для ПП60х27  ПРЕМИУМ  2019  Ноябрь      4364
# 1  10690746  Мешок д/мусора ткан.пропилен.950х550мм  2019  Ноябрь      2616
# 2  10690746  Мешок д/мусора ткан.пропилен.950х550мм  2019  Апрель      2395
# 3  12531431            БЛОКИ YTONG 625Х250Х100 D500  2019    Июнь      2307
# 4  12531431            БЛОКИ YTONG 625Х250Х100 D500  2019    Март      1982

# %%
data_quantity2 = pd.read_csv(
       'quantity/2.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity2.head()
# Out:
#         Art                                      Name  Year    Month  Quantity
# 0  12750159        Фанера ФК 8мм 1525х1525 4/4 нешлиф  2019  Октябрь      1500
# 1  81977449  Пан.МДФ 2600x238x6мм Дуб Мальборк 0,62м2  2019      Май       480
# 2  18324417               Угол ПВХ 20х20х2700мм Белый  2019   Август       417
# 3  18324548               Угол ПВХ 30х30х2700мм Белый  2019   Август       415
# 4  18324548               Угол ПВХ 30х30х2700мм Белый  2019     Июнь       405

# %%
data_quantity3 = pd.read_csv(
       'quantity/3.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity3.head()
# Out:
#         Art                                      Name  Year     Month  \
# 0  17921295  Розетка с/з с защ-й от дет керам. цв. бе  2019      Июль
# 1  10061739       Выкл автомат. 1Р, C 16А 4,5 kA  АВВ  2019   Октябрь
# 2  11842297     Кабель UTP cat5e 4х2х0,52 отрез сталь  2019      Март
# 3  11842297     Кабель UTP cat5e 4х2х0,52 отрез сталь  2019  Сентябрь
# 4  11842326     Кабель FTP cat5e 4х2х0,52 отрез сталь  2019    Август
#
#    Quantity
# 0      1517
# 1      1086
# 2      1035
# 3      1033
# 4       890

# %%
data_quantity4 = pd.read_csv(
       'quantity/4.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity4.head()
# Out:
#         Art                                 Name  Year     Month  Quantity
# 0  13654484  Перчатки х/б ПВХ-обливные, 13 класс  2019    Август      6024
# 1  13654484  Перчатки х/б ПВХ-обливные, 13 класс  2019    Апрель      5153
# 2  13654484  Перчатки х/б ПВХ-обливные, 13 класс  2019       Май      4903
# 3  13654484  Перчатки х/б ПВХ-обливные, 13 класс  2019      Июль      4714
# 4  13654484  Перчатки х/б ПВХ-обливные, 13 класс  2019  Сентябрь      4481

# %%
data_quantity5 = pd.read_csv(
       'quantity/5.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity5.head()
# Out:
#         Art                             Name  Year    Month  Quantity
# 0  82200463  Ковр/п иглопр Austin 78 черн 2м  2019  Октябрь      3661
# 1  14334335   ЛЦ Плинтус ПВХ  Бук 47ммх2,5 м  2019     Март      1048
# 2  14334571      ЛЦ Соединитель Бук 2шт 47мм  2019     Март       515
# 3  14334511     ЛЦ Угол Внешний Бук 2шт 47мм  2019     Март       351
# 4  14334394  ЛЦ Угол внутренний Бук 2шт 47мм  2019     Март       328

# %%
data_quantity6 = pd.read_csv(
       'quantity/6.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity6.head()
# Out:
#         Art                                      Name  Year    Month  Quantity
# 0  82367352        Крестик для плитки 2,0 мм (100 шт)  2020   Январь      1004
# 1  82367352        Крестик для плитки 2,0 мм (100 шт)  2019   Ноябрь       904
# 2  10977309  Крестики д/кафельной плитки 2,0мм(100шт)  2019     Июнь       698
# 3  10977309  Крестики д/кафельной плитки 2,0мм(100шт)  2019   Август       677
# 4  18701606  ТОП1000 МОЗ СТЕКЛ ГОЛУБ МИКС 327Х327Х4ММ  2019  Декабрь       610

# %%
data_quantity7 = pd.read_csv(
       'quantity/7.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity7.head()
# Out:
#         Art                                 Name  Year    Month  Quantity
# 0  13730889        Сиденье для унитаза "V" белое  2020  Февраль       150
# 1  18860771                         Штанга 60см.  2019  Февраль        90
# 2  13454749  ЛЦ ШЛАНГ Д/ДУША ИМП-ИМП МЕТАЛЛ 1,5М  2019      Май        82
# 3  12281559    Бачок д-унитаза модель евро с арм  2019  Октябрь        78
# 4  18857951          ЛЦ душ.лейка ИСТРА 1 реж.хр  2019     Июль        71

# %%
data_quantity8 = pd.read_csv(
       'quantity/8.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity8.head()
# Out:
#         Art                   Name  Year     Month  Quantity
# 0  13563566  УГОЛЬНИК ПП D20 90ГР.  2019    Ноябрь      1183
# 1  13563566  УГОЛЬНИК ПП D20 90ГР.  2019   Октябрь      1160
# 2  13563566  УГОЛЬНИК ПП D20 90ГР.  2019      Март      1127
# 3  13563566  УГОЛЬНИК ПП D20 90ГР.  2019  Сентябрь      1060
# 4  11348635    Крепеж ПП трубы D20  2019    Август       998

# %%
data_quantity9 = pd.read_csv(
       'quantity/9.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity9.head()
# Out:
#         Art                                      Name  Year   Month  Quantity
# 0  12290703                Регулятор роста Циркон,1мл  2019    Март       850
# 1  12290690           Регулятор роста Эпин экстра,1мл  2019    Март       753
# 2  17956480  КОРНЕВИН Стим-р Образ-я, роста корней 5Г  2019    Март       445
# 3  18021889      Леска д/триммера"Круглая" 2,0мм, 15м  2019  Апрель       240
# 4  12290703                Регулятор роста Циркон,1мл  2019  Апрель       207

# %%
data_quantity10 = pd.read_csv(
       'quantity/10.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity10.head()
# Out:
#         Art                           Name  Year     Month  Quantity
# 0  16965675            Уголок оц._30x30x30  2020    Январь       680
# 1  16965675            Уголок оц._30x30x30  2019   Февраль       541
# 2  16965763     Уголок оц. 25х25х14х1,75мм  2019   Февраль       536
# 3  12322322  Анкерный болт с гайкой 10х 50  2019  Сентябрь       486
# 4  18739145      Уголок соед. 40х40х40х1,8  2019    Апрель       464

# %%
data_quantity11 = pd.read_csv(
       'quantity/11.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity11.head()
# Out:
#         Art                               Name  Year     Month  Quantity
# 0  81956695  CR_МАЛЯРНАЯ ЛЕНТА DEXTER 50ММX50М  2019    Август      2127
# 1  81956695  CR_МАЛЯРНАЯ ЛЕНТА DEXTER 50ММX50М  2019      Июль      1784
# 2  81956695  CR_МАЛЯРНАЯ ЛЕНТА DEXTER 50ММX50М  2019  Сентябрь      1505
# 3  81956695  CR_МАЛЯРНАЯ ЛЕНТА DEXTER 50ММX50М  2019    Апрель      1160
# 4  81956695  CR_МАЛЯРНАЯ ЛЕНТА DEXTER 50ММX50М  2019   Октябрь      1044

# %%
data_quantity12 = pd.read_csv(
       'quantity/12.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity12.head()
# Out:
#         Art                                 Name  Year    Month  Quantity
# 0  16877296   Плинтус потолочный экстр. LX-23 2м  2019   Январь       783
# 1  13273091  ЛЦ Плинтус потол экструд бел A09 2м  2020  Февраль       390
# 2  17983832    ЛЦ Обои 0,53х10,05 бум. Марс беж.  2020   Январь       360
# 3  11623641          Плинтус потол экструд MF 2м  2019     Июнь       358
# 4  17983841    ЛЦ Обои 0,53х10,05 бум. Марс кор.  2019     Июнь       280

# %%
data_quantity13 = pd.read_csv(
       'quantity/13.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity13.head()
# Out:
#         Art                                      Name  Year    Month  Quantity
# 0  81980462  Лампа накал RADIUM стандарт 95W,E27,проз  2019  Декабрь       606
# 1  12215543   Лампа люм.OSRAM 590мм,18W,T8,6500К /765  2019   Ноябрь       499
# 2  12215543   Лампа люм.OSRAM 590мм,18W,T8,6500К /765  2019   Август       414
# 3  18195424      ЛЦ Спот встр кругл сталь GU5.3 белый  2019   Апрель       319
# 4  81944920   ЛампаLED G45 шар 7Вт 230В 4000К E27 IEK  2019   Август       315

# %%
data_quantity14 = pd.read_csv(
       'quantity/14.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity14.head()
# Out:
#         Art                                 Name  Year   Month  Quantity
# 0  16938298     Короб д/переезда картон 56Х32Х40  2019     Май       750
# 1  16938298     Короб д/переезда картон 56Х32Х40  2019  Январь       458
# 2  16938298     Короб д/переезда картон 56Х32Х40  2019    Июль       378
# 3  16938298     Короб д/переезда картон 56Х32Х40  2019    Июнь       291
# 4  14104978  Короб д/переезда картон 40х30х20 см  2019     Май       279

# %%
data_quantity15 = pd.read_csv(
       'quantity/15.csv',
       sep=';',
       names=['Art', 'Name', 'Year', 'Month', 'Quantity'],
       encoding='utf-8'       
    )
data_quantity15.head()
# Out:
#         Art                                 Name  Year    Month  Quantity
# 0  18239394  Ручка JET107 м.ц.128мм. браш.никель  2019   Август        47
# 1  14397424                      К-т петель 2 шт  2019   Август        43
# 2  14397432         К-т петель с доводчиком 2 шт  2019  Октябрь        38
# 3  14397432         К-т петель с доводчиком 2 шт  2019   Ноябрь        34
# 4  15441431      Ручка Бронза Нэнси JET219мц96мм  2019   Ноябрь        34

# %%
data_quantity15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215 entries, 0 to 2214
# Data columns (total 5 columns):
# Art         2215 non-null int64
# Name        2215 non-null object
# Year        2215 non-null int64
# Month       2215 non-null object
# Quantity    2215 non-null int64
# dtypes: int64(3), object(2)
# memory usage: 86.6+ KB

# %% [markdown]
# ### 2. выполним преобразование данных

# %%
#удалим данные за 2020год, оставим только 2019
data_cost1 = data_cost1.loc[data_cost1.Year!=2020]
data_cost1
# Out:
#            Art                                    Name  CostRub  Year  \
# 0     10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   385818  2019
# 1     10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   366447  2019
# 2     10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   292615  2019
# 3     10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   290458  2019
# 4     10073940  Штукатурка гипсовая КНАУФ Ротбанд 30кг   260065  2019
# ...        ...                                     ...      ...   ...
# 4043  18785619              Полиуретановый зимний клей     -458  2019
# 4044  18529877              Клей-пена PENOPLEX FASTFIX     -700  2019
# 4046  14238167                     ЛЦ Стяжка пола 25кг     -864  2019
# 4047  13672877     Стяжка пола PERFEKTA Фиброслой 25кг     -985  2019
# 4048  82009436  Виброизолирующий подвес "Ультракустик"    -4512  2019
#
#          Month
# 0         Июль
# 1      Февраль
# 2      Декабрь
# 3       Август
# 4         Март
# ...        ...
# ...

# %%
data_quantity1 = data_quantity1.loc[data_quantity1.Year!=2020]
data_quantity1
# Out:
#            Art                                    Name  Year     Month  \
# 0     14394434      Прямой подвес для ПП60х27  ПРЕМИУМ  2019    Ноябрь
# 1     10690746  Мешок д/мусора ткан.пропилен.950х550мм  2019    Ноябрь
# 2     10690746  Мешок д/мусора ткан.пропилен.950х550мм  2019    Апрель
# 3     12531431            БЛОКИ YTONG 625Х250Х100 D500  2019      Июнь
# 4     12531431            БЛОКИ YTONG 625Х250Х100 D500  2019      Март
# ...        ...                                     ...   ...       ...
# 4165  82127095  Плитка дек. Вельс брик белая 0,75 м.кв  2019   Декабрь
# 4166  18529877              Клей-пена PENOPLEX FASTFIX  2019   Декабрь
# 4169  13672877     Стяжка пола PERFEKTA Фиброслой 25кг  2019   Октябрь
# 4170  14238167                     ЛЦ Стяжка пола 25кг  2019  Сентябрь
# 4172  82009436  Виброизолирующий подвес "Ультракустик"  2019    Ноябрь
#
#       Quantity
# 0         4364
# 1         2616
# 2         2395
# 3         2307
# 4         1982
# ...        ...
# ...

# %%
#название артикулов поднимем в верхний регистр
data_cost1.Name = data_cost1.Name.str.upper()
data_cost1.head()
# Out:
#         Art                                    Name  CostRub  Year    Month
# 0  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   385818  2019     Июль
# 1  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   366447  2019  Февраль
# 2  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   292615  2019  Декабрь
# 3  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   290458  2019   Август
# 4  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   260065  2019     Март

# %%
#название артикулов поднимем в верхний регистр
data_quantity1.Name = data_quantity1.Name.str.upper()
data_quantity1.head()
# Out:
#         Art                                    Name  Year   Month  Quantity
# 0  14394434      ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ  2019  Ноябрь      4364
# 1  10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019  Ноябрь      2616
# 2  10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019  Апрель      2395
# 3  12531431            БЛОКИ YTONG 625Х250Х100 D500  2019    Июнь      2307
# 4  12531431            БЛОКИ YTONG 625Х250Х100 D500  2019    Март      1982

# %% [markdown]
# ### заменяем месяц

# %%
for fl in range(1,16):
    data_cost[fl].loc[(data_cost[fl].Month == 'Январь'), 'MonthNum'] = '01'
    data_cost[fl].loc[(data_cost[fl].Month == 'Февраль'), 'MonthNum'] = '02'
    data_cost[fl].loc[(data_cost[fl].Month == 'Март'), 'MonthNum'] = '03'
    data_cost[fl].loc[(data_cost[fl].Month == 'Апрель'), 'MonthNum'] = '04'
    data_cost[fl].loc[(data_cost[fl].Month == 'Май'), 'MonthNum'] = '05'
    data_cost[fl].loc[(data_cost[fl].Month == 'Июнь'), 'MonthNum'] = '06'
    data_cost[fl].loc[(data_cost[fl].Month == 'Июль'), 'MonthNum'] = '07'
    data_cost[fl].loc[(data_cost[fl].Month == 'Август'), 'MonthNum'] = '08'
    data_cost[fl].loc[(data_cost[fl].Month == 'Сентябрь'), 'MonthNum'] = '09'
    data_cost[fl].loc[(data_cost[fl].Month == 'Октябрь'), 'MonthNum'] = '10'
    data_cost[fl].loc[(data_cost[fl].Month == 'Ноябрь'), 'MonthNum'] = '11'
    data_cost[fl].loc[(data_cost[fl].Month == 'Декабрь'), 'MonthNum'] = '12'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-e5be429c10b0> in <module>
#       1 for fl in range(1,16):
# ----> 2     data_cost[fl].loc[(data_cost[fl].Month == 'Январь'), 'MonthNum'] = '01'
#       3     data_cost[fl].loc[(data_cost[fl].Month == 'Февраль'), 'MonthNum'] = '02'
#       4     data_cost[fl].loc[(data_cost[fl].Month == 'Март'), 'MonthNum'] = '03'
#       5     data_cost[fl].loc[(data_cost[fl].Month == 'Апрель'), 'MonthNum'] = '04'
#
# NameError: name 'data_cost' is not defined

# %%
data_cost1.loc[(data_cost1.Month == 'Январь'), 'MonthNum'] = '01'
data_cost1.loc[(data_cost1.Month == 'Февраль'), 'MonthNum'] = '02'
data_cost1.loc[(data_cost1.Month == 'Март'), 'MonthNum'] = '03'
data_cost1.loc[(data_cost1.Month == 'Апрель'), 'MonthNum'] = '04'
data_cost1.loc[(data_cost1.Month == 'Май'), 'MonthNum'] = '05'
data_cost1.loc[(data_cost1.Month == 'Июнь'), 'MonthNum'] = '06'
data_cost1.loc[(data_cost1.Month == 'Июль'), 'MonthNum'] = '07'
data_cost1.loc[(data_cost1.Month == 'Август'), 'MonthNum'] = '08'
data_cost1.loc[(data_cost1.Month == 'Сентябрь'), 'MonthNum'] = '09'
data_cost1.loc[(data_cost1.Month == 'Октябрь'), 'MonthNum'] = '10'
data_cost1.loc[(data_cost1.Month == 'Ноябрь'), 'MonthNum'] = '11'
data_cost1.loc[(data_cost1.Month == 'Декабрь'), 'MonthNum'] = '12'
data_cost1.head(20)
# Out:
#          Art                                      Name  CostRub  Year  \
# 0   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   385818  2019
# 1   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   366447  2019
# 2   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   292615  2019
# 3   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   290458  2019
# 4   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   260065  2019
# 5   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   239401  2019
# 6   10072681  ГСП-А КНАУФ 2500Х1200Х12,5ММ (СТАНДАРТ.)   232100  2019
# 8   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   222882  2019
# 9   18478820                   ПЕСКОБЕТОН М 300, 40 КГ   216836  2019
# 10  81963566         ЦЕМЕНТ EXTRACEM 500 HOLCIM, 50 КГ   205808  2019
# 11  81963566         ЦЕМЕНТ EXTRACEM 500 HOLCIM, 50 КГ   200180  2019
# 12  10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   187486  2019
# ...

# %%
data_cost2.loc[(data_cost2.Month == 'Январь'), 'MonthNum'] = '01'
data_cost2.loc[(data_cost2.Month == 'Февраль'), 'MonthNum'] = '02'
data_cost2.loc[(data_cost2.Month == 'Март'), 'MonthNum'] = '03'
data_cost2.loc[(data_cost2.Month == 'Апрель'), 'MonthNum'] = '04'
data_cost2.loc[(data_cost2.Month == 'Май'), 'MonthNum'] = '05'
data_cost2.loc[(data_cost2.Month == 'Июнь'), 'MonthNum'] = '06'
data_cost2.loc[(data_cost2.Month == 'Июль'), 'MonthNum'] = '07'
data_cost2.loc[(data_cost2.Month == 'Август'), 'MonthNum'] = '08'
data_cost2.loc[(data_cost2.Month == 'Сентябрь'), 'MonthNum'] = '09'
data_cost2.loc[(data_cost2.Month == 'Октябрь'), 'MonthNum'] = '10'
data_cost2.loc[(data_cost2.Month == 'Ноябрь'), 'MonthNum'] = '11'
data_cost2.loc[(data_cost2.Month == 'Декабрь'), 'MonthNum'] = '12'
data_cost2.head(20)
# Out:
#          Art                                      Name  CostRub  Year  \
# 0   12750159        Фанера ФК 8мм 1525х1525 4/4 нешлиф   690000  2019
# 1   81977449  Пан.МДФ 2600x238x6мм Дуб Мальборк 0,62м2   103680  2019
# 2   81947516   ДПГ ARTENS ВЕЛДОН МОККО 2000X800 С ФУРН   100737  2019
# 3   18693677           OSB-3 11MM ULTRALAM 1250Х2500ММ    90385  2019
# 4   17854491       Стекло ПЭТ-А прозрачн.1525х1025х3мм    79860  2019
# 5   18693685           OSB-3 15MM ULTRALAM 1250Х2500ММ    76516  2019
# 6   81947963      ЕВРОВАГОНКА ХВ ОПТИМА 12,5Х96Х3000ММ    75544  2019
# 7   18693669           OSB-3 8 MM ULTRALAM 1250Х2500ММ    69333  2019
# 8   81947963      ЕВРОВАГОНКА ХВ ОПТИМА 12,5Х96Х3000ММ    67760  2019
# 9   18693677           OSB-3 11MM ULTRALAM 1250Х2500ММ    67234  2019
# 10  11988093         Фанера ФК 12мм 1525х1525 3/4 шлиф    58674  2019
# 11  11988093         Фанера ФК 12мм 1525х1525 3/4 шлиф    58174  2019
# ...

# %%
data_quantity1.loc[(data_quantity1.Month == 'Январь'), 'MonthNum'] = '01'
data_quantity1.loc[(data_quantity1.Month == 'Февраль'), 'MonthNum'] = '02'
data_quantity1.loc[(data_quantity1.Month == 'Март'), 'MonthNum'] = '03'
data_quantity1.loc[(data_quantity1.Month == 'Апрель'), 'MonthNum'] = '04'
data_quantity1.loc[(data_quantity1.Month == 'Май'), 'MonthNum'] = '05'
data_quantity1.loc[(data_quantity1.Month == 'Июнь'), 'MonthNum'] = '06'
data_quantity1.loc[(data_quantity1.Month == 'Июль'), 'MonthNum'] = '07'
data_quantity1.loc[(data_quantity1.Month == 'Август'), 'MonthNum'] = '08'
data_quantity1.loc[(data_quantity1.Month == 'Сентябрь'), 'MonthNum'] = '09'
data_quantity1.loc[(data_quantity1.Month == 'Октябрь'), 'MonthNum'] = '10'
data_quantity1.loc[(data_quantity1.Month == 'Ноябрь'), 'MonthNum'] = '11'
data_quantity1.loc[(data_quantity1.Month == 'Декабрь'), 'MonthNum'] = '12'
data_quantity1.head(20)
# Out:
#          Art                                    Name  Year     Month  \
# 0   14394434      ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ  2019    Ноябрь
# 1   10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019    Ноябрь
# 2   10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019    Апрель
# 3   12531431            БЛОКИ YTONG 625Х250Х100 D500  2019      Июнь
# 4   12531431            БЛОКИ YTONG 625Х250Х100 D500  2019      Март
# 5   14609301         МЕШКИ ДЛЯ МУСОРА 55Х95СМ, 10ШТ.  2019   Декабрь
# 6   12531431            БЛОКИ YTONG 625Х250Х100 D500  2019    Ноябрь
# 7   14394434      ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ  2019    Август
# 8   12531431            БЛОКИ YTONG 625Х250Х100 D500  2019   Октябрь
# 9   14394434      ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ  2019   Декабрь
# 11  14394434      ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ  2019  Сентябрь
# 12  18478820                 ПЕСКОБЕТОН М 300, 40 КГ  2019   Октябрь
# 13  10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019   Октябрь
# ...

# %% [markdown]
# ### формируем период

# %%
def union_date(row):
    return str(row['Year']) + '-' + str(row['MonthNum']) + '-01' 


data_cost1['Period'] = data_cost1.apply(union_date, axis=1)
data_cost1.head()
# Out:
#         Art                                    Name  CostRub  Year    Month  \
# 0  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   385818  2019     Июль
# 1  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   366447  2019  Февраль
# 2  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   292615  2019  Декабрь
# 3  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   290458  2019   Август
# 4  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   260065  2019     Март
#
#   MonthNum      Period
# 0       07  2019-07-01
# 1       02  2019-02-01
# 2       12  2019-12-01
# 3       08  2019-08-01
# 4       03  2019-03-01

# %%
data_cost1['Period'] = data_cost1.Period.astype('datetime64[ns]')
data_cost1
# Out:
#            Art                                    Name  CostRub  Year  \
# 0     10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   385818  2019
# 1     10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   366447  2019
# 2     10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   292615  2019
# 3     10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   290458  2019
# 4     10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ   260065  2019
# ...        ...                                     ...      ...   ...
# 4043  18785619              ПОЛИУРЕТАНОВЫЙ ЗИМНИЙ КЛЕЙ     -458  2019
# 4044  18529877              КЛЕЙ-ПЕНА PENOPLEX FASTFIX     -700  2019
# 4046  14238167                     ЛЦ СТЯЖКА ПОЛА 25КГ     -864  2019
# 4047  13672877     СТЯЖКА ПОЛА PERFEKTA ФИБРОСЛОЙ 25КГ     -985  2019
# 4048  82009436  ВИБРОИЗОЛИРУЮЩИЙ ПОДВЕС "УЛЬТРАКУСТИК"    -4512  2019
#
#          Month MonthNum     Period
# 0         Июль       07 2019-07-01
# 1      Февраль       02 2019-02-01
# ...

# %%
data_cost1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3682 entries, 0 to 4048
# Data columns (total 7 columns):
# Art         3682 non-null int64
# Name        3682 non-null object
# CostRub     3682 non-null int64
# Year        3682 non-null int64
# Month       3682 non-null object
# MonthNum    3682 non-null object
# Period      3682 non-null datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(3)
# memory usage: 230.1+ KB

# %%
data_quantity1['Period'] = data_quantity1.apply(union_date, axis=1)
data_quantity1.head()
# Out:
#         Art                                    Name  Year   Month  Quantity  \
# 0  14394434      ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ  2019  Ноябрь      4364
# 1  10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019  Ноябрь      2616
# 2  10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019  Апрель      2395
# 3  12531431            БЛОКИ YTONG 625Х250Х100 D500  2019    Июнь      2307
# 4  12531431            БЛОКИ YTONG 625Х250Х100 D500  2019    Март      1982
#
#   MonthNum      Period
# 0       11  2019-11-01
# 1       11  2019-11-01
# 2       04  2019-04-01
# 3       06  2019-06-01
# 4       03  2019-03-01

# %%
data_quantity1['Period'] = data_quantity1.Period.astype('datetime64[ns]')
data_quantity1
# Out:
#            Art                                    Name  Year     Month  \
# 0     14394434      ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ  2019    Ноябрь
# 1     10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019    Ноябрь
# 2     10690746  МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ  2019    Апрель
# 3     12531431            БЛОКИ YTONG 625Х250Х100 D500  2019      Июнь
# 4     12531431            БЛОКИ YTONG 625Х250Х100 D500  2019      Март
# ...        ...                                     ...   ...       ...
# 4165  82127095  ПЛИТКА ДЕК. ВЕЛЬС БРИК БЕЛАЯ 0,75 М.КВ  2019   Декабрь
# 4166  18529877              КЛЕЙ-ПЕНА PENOPLEX FASTFIX  2019   Декабрь
# 4169  13672877     СТЯЖКА ПОЛА PERFEKTA ФИБРОСЛОЙ 25КГ  2019   Октябрь
# 4170  14238167                     ЛЦ СТЯЖКА ПОЛА 25КГ  2019  Сентябрь
# 4172  82009436  ВИБРОИЗОЛИРУЮЩИЙ ПОДВЕС "УЛЬТРАКУСТИК"  2019    Ноябрь
#
#       Quantity MonthNum     Period
# 0         4364       11 2019-11-01
# 1         2616       11 2019-11-01
# ...

# %% [markdown]
# ### 3.подсчет итогов

# %%
data_cost1_sum = data_cost1.groupby(['Art','Name'])['CostRub'].sum().reset_index()\
    .sort_values('CostRub', ascending=False)
data_cost1_sum.head()
# Out:
#           Art                                      Name  CostRub
# 16   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ  2907704
# 406  18478820                   ПЕСКОБЕТОН М 300, 40 КГ  1496698
# 440  18700540  МЕШОК Д/МУСОР ТКАН/ПРОПИЛЕН.950Х550 50ШТ  1413189
# 229  15095305  ШПАКЛЕВКА ПОЛИМЕР.WEBER.VETONIT LR  20КГ  1330062
# 234  15163427                     ПЕСКОБЕТОН 30КГ AXTON  1225102

# %%
data_cost1_sum['Art'] = data_cost1_sum.Art.astype('object')

# %%
data_cost1_sum.style.bar()
# Out:
# <style  type="text/css" >
#     #T_b07a55ae_5285_11ea_904c_3ca067dbb1d8row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_b07a55ae_5285_11ea_904c_3ca067dbb1d8row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.5%, transparent 51.5%);
#         }    #T_b07a55ae_5285_11ea_904c_3ca067dbb1d8row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.6%, transparent 48.6%);
#         }    #T_b07a55ae_5285_11ea_904c_3ca067dbb1d8row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 45.8%, transparent 45.8%);
#         }    #T_b07a55ae_5285_11ea_904c_3ca067dbb1d8row4_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %%
data_cost1_sum.to_csv('cost_sum_01.csv', sep=';', index=True, index_label=True, encoding='utf-8')

# %%
data_cost1_top30 = data_cost1_sum.head(30).reset_index().reset_index()
data_cost1_top30
# Out:
#     level_0  index       Art                                      Name  \
# 0         0     16  10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 1         1    406  18478820                   ПЕСКОБЕТОН М 300, 40 КГ
# 2         2    440  18700540  МЕШОК Д/МУСОР ТКАН/ПРОПИЛЕН.950Х550 50ШТ
# 3         3    229  15095305  ШПАКЛЕВКА ПОЛИМЕР.WEBER.VETONIT LR  20КГ
# 4         4    234  15163427                     ПЕСКОБЕТОН 30КГ AXTON
# 5         5    495  81963566         ЦЕМЕНТ EXTRACEM 500 HOLCIM, 50 КГ
# 6         6     65  12531431              БЛОКИ YTONG 625Х250Х100 D500
# 7         7     14  10072681  ГСП-А КНАУФ 2500Х1200Х12,5ММ (СТАНДАРТ.)
# 8         8    436  18630553  ПЛИТА ПОТОЛОЧНАЯ TRENTO AMF 13 ММ (18 ШТ
# 9         9     56  12095334              ПРОФИЛЬ ПП 60Х27ММ L3М КНАУФ
# 10       10     96  12756948              ПРОФИЛЬ ПС 50Х50ММ L3М КНАУФ
# 11       11     15  10072745  ГСП-Н2 КНАУФ 2500Х1200Х12,5ММ (ВЛАГОСТ.)
# ...

# %%
data_quantity1_sum = data_quantity1.groupby(['Art','Name'])['Quantity'].sum().reset_index()\
    .sort_values('Quantity', ascending=False)

# %%
data_quantity1_sum['Art'] = data_quantity1_sum.Art.astype('object')

# %%
data_quantity1_sum.style.bar()
# Out:
# <style  type="text/css" >
#     #T_cc5cf506_5285_11ea_b416_3ca067dbb1d8row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_cc5cf506_5285_11ea_b416_3ca067dbb1d8row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.0%, transparent 78.0%);
#         }    #T_cc5cf506_5285_11ea_b416_3ca067dbb1d8row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 70.3%, transparent 70.3%);
#         }    #T_cc5cf506_5285_11ea_b416_3ca067dbb1d8row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.9%, transparent 59.9%);
#         }    #T_cc5cf506_5285_11ea_b416_3ca067dbb1d8row4_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %%
data_quantity1_sum.to_csv('quantity_sum_01.csv', sep=';', index=True, index_label=True, encoding='utf-8')

# %%
data_quantity1_top30 = data_quantity1_sum.head(30).reset_index().reset_index()
data_quantity1_top30
# Out:
#     level_0  index       Art                                      Name  \
# 0         0    211  14394434        ПРЯМОЙ ПОДВЕС ДЛЯ ПП60Х27  ПРЕМИУМ
# 1         1     65  12531431              БЛОКИ YTONG 625Х250Х100 D500
# 2         2     25  10690746    МЕШОК Д/МУСОРА ТКАН.ПРОПИЛЕН.950Х550ММ
# 3         3    406  18478820                   ПЕСКОБЕТОН М 300, 40 КГ
# 4         4    234  15163427                     ПЕСКОБЕТОН 30КГ AXTON
# 5         5    215  14609301           МЕШКИ ДЛЯ МУСОРА 55Х95СМ, 10ШТ.
# 6         6    103  12845385       МЕШОК Д/МУСОРА 1СОРТ БЕЛЫЙ 55Х95СМ.
# 7         7    305  16126433   ПРОФИЛЬ УГЛОЗАЩ. ОЦ. 20Х20ММ 3М ПРЕМИУМ
# 8         8    307  16126450          ПРОФИЛЬ МАЯЧКОВЫЙ 6ММ 3М ПРЕМИУМ
# 9         9     16  10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 10       10    220  15052621         Т-ПРОФИЛЬ 24ММ БЕЛЫЙ L0,6М ЭКОНОМ
# 11       11     71  12627951      СУХАЯ СМЕСЬ УНИВЕРСАЛЬНАЯ М-150 25КГ
# ...

# %%
#объединим итоговые сумму продаж и кол-во
data_sum1 = data_cost1_sum.merge(data_quantity1_sum, how='left', left_on=['Art','Name'], right_on=['Art','Name'])
data_sum1.head()
# Out:
#         Art                                      Name  CostRub  Quantity
# 0  10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ  2907704      7169
# 1  18478820                   ПЕСКОБЕТОН М 300, 40 КГ  1496698     10668
# 2  18700540  МЕШОК Д/МУСОР ТКАН/ПРОПИЛЕН.950Х550 50ШТ  1413189      4336
# 3  15095305  ШПАКЛЕВКА ПОЛИМЕР.WEBER.VETONIT LR  20КГ  1330062      2290
# 4  15163427                     ПЕСКОБЕТОН 30КГ AXTON  1225102      9704

# %%
data_sum1.reset_index()
# Out:
#      index       Art                                      Name  CostRub  \
# 0        0  10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ  2907704
# 1        1  18478820                   ПЕСКОБЕТОН М 300, 40 КГ  1496698
# 2        2  18700540  МЕШОК Д/МУСОР ТКАН/ПРОПИЛЕН.950Х550 50ШТ  1413189
# 3        3  15095305  ШПАКЛЕВКА ПОЛИМЕР.WEBER.VETONIT LR  20КГ  1330062
# 4        4  15163427                     ПЕСКОБЕТОН 30КГ AXTON  1225102
# ..     ...       ...                                       ...      ...
# 560    560  12689917       СЕТКА КЛАДОЧНАЯ 50Х50Х2,5ММ 0,5Х15М        0
# 561    561  10008671        ЖЕЛОБ ВОДОСТОЧ.КРАСНЫЙ 2,5М  125ММ        0
# 562    562  81933226                   1М VERAT ТРУБА, ЗЕЛЕНЫЙ        0
# 563    563  15382451   КОМПЛЕКТ ПОТОЛКА ДУО 2Х2М БЕЛ.МАТ./ХРОМ        0
# 564    564  18529877                КЛЕЙ-ПЕНА PENOPLEX FASTFIX     -700
#
#      Quantity
# 0        7169
# 1       10668
# 2        4336
# 3        2290
# 4        9704
# ...

# %%
data_sum1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 564
# Data columns (total 4 columns):
# Art         565 non-null object
# Name        565 non-null object
# CostRub     565 non-null int64
# Quantity    565 non-null int64
# dtypes: int64(2), object(2)
# memory usage: 22.1+ KB

# %%
data_sum1.to_csv('sum_01.csv', sep=';', index=True, index_label=True, encoding='utf-8')

# %% [markdown]
# ### 4. объединение в сводную таблицу

# %%
data_cost1_rez=data_cost1.pivot_table(index=['Art', 'Name'], columns='Period', values='CostRub', fill_value='0')
data_cost1_rez
# Out:
# Period                                          2019-01-01 2019-02-01  \
# Art      Name
# 923538   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON 1Л             94         47
# 923544   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON  5Л           660        495
# 923550   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON 10Л          4538       6750
# 923558   ГРУНТ-КОНЦЕНТРАТ Д/СУХ ПОМЕЩ AXTON 10Л        854        854
# 923562   ГРУНТ ДЛЯ ВЛАЖНЫХ ПОМЕЩЕНИЙ AXTON 1Л            0         51
# ...                                                    ...        ...
# 82441771 ЛЦ БЕТОНОСМЕСИТЕЛЬ "ЗЕМЛЯК БСЭ-63"              0          0
# 82456044 ПОРТЛАНДЦЕМЕНТ ЦЕМ II/А-И 42.5, 25 КГ           0          0
# 82456045 ПОРТЛАНДЦЕМЕНТ ЦЕМ II/А-И 42.5, 50 КГ           0          0
# 82458402 ПЛЕНКА АРМИРОВАННАЯ 350МКР. 2Х10М               0          0
# 82479770 КЕРАМЗИТ ФР.10-20 ММ, 40Л.                      0          0
#
# Period                                          2019-03-01 2019-04-01  \
# Art      Name
# ...

# %%
data1_top30 = data_sum1.merge(data_cost1_rez, how='left', left_on=['Art','Name'], right_on=['Art','Name'])
data1_top30
# Out:
#          Art                                      Name  CostRub  \
# 0   10073940    ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ  2907704
# 1   18478820                   ПЕСКОБЕТОН М 300, 40 КГ  1496698
# 2   18700540  МЕШОК Д/МУСОР ТКАН/ПРОПИЛЕН.950Х550 50ШТ  1413189
# 3   15095305  ШПАКЛЕВКА ПОЛИМЕР.WEBER.VETONIT LR  20КГ  1330062
# 4   15163427                     ПЕСКОБЕТОН 30КГ AXTON  1225102
# 5   81963566         ЦЕМЕНТ EXTRACEM 500 HOLCIM, 50 КГ  1141228
# 6   12531431              БЛОКИ YTONG 625Х250Х100 D500  1009031
# 7   10072681  ГСП-А КНАУФ 2500Х1200Х12,5ММ (СТАНДАРТ.)   842830
# 8   18630553  ПЛИТА ПОТОЛОЧНАЯ TRENTO AMF 13 ММ (18 ШТ   840697
# 9   12095334              ПРОФИЛЬ ПП 60Х27ММ L3М КНАУФ   810331
# 10  12756948              ПРОФИЛЬ ПС 50Х50ММ L3М КНАУФ   735789
# 11  10072745  ГСП-Н2 КНАУФ 2500Х1200Х12,5ММ (ВЛАГОСТ.)   680545
# 12  10074281         КЛЕЙ ДЛЯ ПЛИТКИ КНАУФ ФЛИЗЕН 25КГ   674389
# 13  12593034             ЛЦ ГИПСОКАРТОН 2500 1200 12,5   652083
# ...

# %% [markdown]
# ### TOP30 по продажам

# %%
#top30 по продажам
data1_top30_2 = data_cost1_top30.merge(data_cost1, how='left', left_on=['Art','Name'], right_on=['Art','Name'])
data1_top30_2
# Out:
#      level_0  index       Art                                    Name  \
# 0          0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 1          0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 2          0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 3          0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 4          0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# ..       ...    ...       ...                                     ...
# 351       29     37  11313264     ШТУКАТУРКА ГИПСОВАЯ ВОЛМА-СЛОЙ 30КГ
# 352       29     37  11313264     ШТУКАТУРКА ГИПСОВАЯ ВОЛМА-СЛОЙ 30КГ
# 353       29     37  11313264     ШТУКАТУРКА ГИПСОВАЯ ВОЛМА-СЛОЙ 30КГ
# 354       29     37  11313264     ШТУКАТУРКА ГИПСОВАЯ ВОЛМА-СЛОЙ 30КГ
# 355       29     37  11313264     ШТУКАТУРКА ГИПСОВАЯ ВОЛМА-СЛОЙ 30КГ
#
#      CostRub_x  CostRub_y  Year     Month MonthNum     Period
# 0      2907704     385818  2019      Июль       07 2019-07-01
# ...

# %%
def union_level(row):
    str_lev=''
    if row['level_0']+1<10:
        str_lev = '0' + str(row['level_0']+1)
    else:
        str_lev = str(row['level_0']+1)
    return str_lev + '_' + str(row['Art'])


data1_top30_2['TopCost_Art'] = data1_top30_2.apply(union_level, axis=1)
data1_top30_2.head()
# Out:
#    level_0  index       Art                                    Name  \
# 0        0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 1        0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 2        0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 3        0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
# 4        0     16  10073940  ШТУКАТУРКА ГИПСОВАЯ КНАУФ РОТБАНД 30КГ
#
#    CostRub_x  CostRub_y  Year    Month MonthNum     Period    Level_Art  \
# 0    2907704     385818  2019     Июль       07 2019-07-01  01_10073940
# 1    2907704     366447  2019  Февраль       02 2019-02-01  01_10073940
# 2    2907704     292615  2019  Декабрь       12 2019-12-01  01_10073940
# 3    2907704     290458  2019   Август       08 2019-08-01  01_10073940
# 4    2907704     260065  2019     Март       03 2019-03-01  01_10073940
#
#        Top_Art  TopCost_Art
# 0  01_10073940  01_10073940
# 1  01_10073940  01_10073940
# 2  01_10073940  01_10073940
# ...

# %%
data_cost1_rez2 = data1_top30_2.pivot_table(
                                index='Period',
                                columns='TopCost_Art',
                                values='CostRub_y',
                                fill_value='0').applymap(int)
data_cost1_rez2
# Out:
# TopCost_Art  01_10073940  02_18478820  03_18700540  04_15095305  05_15163427  \
# Period
# 2019-01-01        127991        76786        65500        80379        26496
# 2019-02-01        366447       114986       102760        74813        42368
# 2019-03-01        260065       109095       168278       113018       158592
# 2019-04-01        176113       133560       162243       156864       103296
# 2019-05-01        239401       101780        89775       101328       126431
# 2019-06-01        182059       138600       105840       113875       116928
# 2019-07-01        385818        72800       126628        95961        92232
# 2019-08-01        290458       152048       147705        98279       106797
# 2019-09-01        222882       146994       109965       167790        82656
# 2019-10-01        176369       216836       102030        66685       113652
# 2019-11-01        187486       125372       137590       114905       114912
# ...

# %% [markdown]
# ### TOP5 по продажам

# %%
data_cost1_rez2.iloc[:,0:5].describe()
# Out:
# TopCost_Art    01_10073940    02_18478820    03_18700540    04_15095305  \
# count            12.000000      12.000000      12.000000      12.000000
# mean         242308.666667  124724.833333  117765.750000  110838.500000
# std           79766.397151   38308.464906   31061.011721   32029.771079
# min          127991.000000   72800.000000   65500.000000   66685.000000
# 25%          180636.500000  106325.750000  100241.250000   92065.500000
# 50%          231141.500000  120179.000000  107902.500000  107173.000000
# 75%          290997.250000  140698.500000  140118.750000  122720.000000
# max          385818.000000  216836.000000  168278.000000  167790.000000
#
# TopCost_Art    05_15163427
# count            12.000000
# mean         102091.833333
# std           37630.775661
# min           26496.000000
# 25%           89838.000000
# 50%          110224.500000
# 75%          119303.750000
# max          158592.000000

# %%
ax = sns.heatmap(data_cost1_rez2.iloc[:,0:5])

# %%
data_cost1_rez2.iloc[:,0:5].plot()

# %%
data_cost1_rez2.iloc[:,6:11].plot(kind='bar')

# %%
data_cost1_rez2.iloc[:,12:17].plot()

# %%
data_cost1_rez2.iloc[:,12:17].plot(kind='bar')

# %% [markdown]
# ### Top по кол-ву

# %%
data_quantity1_rez=data_quantity1.pivot_table(index=['Art', 'Name'], columns='Period', values='Quantity', fill_value='0')
data_quantity1_rez
# Out:
# Period                                          2019-01-01 2019-02-01  \
# Art      Name
# 923538   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON 1Л              2          1
# 923544   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON  5Л             4          3
# 923550   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON 10Л            17         25
# 923558   ГРУНТ-КОНЦЕНТРАТ Д/СУХ ПОМЕЩ AXTON 10Л          1          1
# 923562   ГРУНТ ДЛЯ ВЛАЖНЫХ ПОМЕЩЕНИЙ AXTON 1Л            0          1
# ...                                                    ...        ...
# 82441771 ЛЦ БЕТОНОСМЕСИТЕЛЬ "ЗЕМЛЯК БСЭ-63"              0          0
# 82456044 ПОРТЛАНДЦЕМЕНТ ЦЕМ II/А-И 42.5, 25 КГ           0          0
# 82456045 ПОРТЛАНДЦЕМЕНТ ЦЕМ II/А-И 42.5, 50 КГ           0          0
# 82458402 ПЛЕНКА АРМИРОВАННАЯ 350МКР. 2Х10М               0          0
# 82479770 КЕРАМЗИТ ФР.10-20 ММ, 40Л.                      0          0
#
# Period                                          2019-03-01 2019-04-01  \
# Art      Name
# ...

# %%
data_rez1 = data_cost1_rez.merge(data_quantity1_rez, how='left', left_on=['Art','Name'], right_on=['Art','Name'])
data_rez1
# Out:
# Period                                          2019-01-01 00:00:00_x  \
# Art      Name
# 923538   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON 1Л                        94
# 923544   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON  5Л                      660
# 923550   ГРУНТ ДЛЯ СУХИХ ПОМЕЩЕНИЙ AXTON 10Л                     4538
# 923558   ГРУНТ-КОНЦЕНТРАТ Д/СУХ ПОМЕЩ AXTON 10Л                   854
# 923562   ГРУНТ ДЛЯ ВЛАЖНЫХ ПОМЕЩЕНИЙ AXTON 1Л                       0
# ...                                                               ...
# 82441771 ЛЦ БЕТОНОСМЕСИТЕЛЬ "ЗЕМЛЯК БСЭ-63"                         0
# 82456044 ПОРТЛАНДЦЕМЕНТ ЦЕМ II/А-И 42.5, 25 КГ                      0
# 82456045 ПОРТЛАНДЦЕМЕНТ ЦЕМ II/А-И 42.5, 50 КГ                      0
# 82458402 ПЛЕНКА АРМИРОВАННАЯ 350МКР. 2Х10М                          0
# 82479770 КЕРАМЗИТ ФР.10-20 ММ, 40Л.                                 0
#
# Period                                          2019-02-01 00:00:00_x  \
# Art      Name
# ...

# %%
data_rez1.to_csv('rez01.csv', sep=';', index=True, index_label=True, encoding='utf-8')

# %%
# ?data_cost1_rez.to_csv
